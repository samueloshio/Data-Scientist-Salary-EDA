# %%
import pandas as pd   # importing library

# %%
df = pd.read_csv('dataset/DataScientist.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0  index                          Job Title  \
# 0           0      0              Senior Data Scientist
# 1           1      1  Data Scientist, Product Analytics
# 2           2      2               Data Science Manager
# 3           3      3                       Data Analyst
# 4           4      4             Director, Data Science
# 5           5      5                     Data Scientist
# 6           6      6            Quantitative Researcher
# 7           7      7    Quantitative Research Associate
# 8           8      8                       AI Scientist
# 9           9      9            Quantitative Researcher
#
#                 Salary Estimate  \
# 0  $111K-$181K (Glassdoor est.)
# 1  $111K-$181K (Glassdoor est.)
# 2  $111K-$181K (Glassdoor est.)
# 3  $111K-$181K (Glassdoor est.)
# 4  $111K-$181K (Glassdoor est.)
# 5  $111K-$181K (Glassdoor est.)
# 6  $111K-$181K (Glassdoor est.)
# 7  $111K-$181K (Glassdoor est.)
# 8  $111K-$181K (Glassdoor est.)
# ...

# %%
df.set_index('index', inplace=True)

# %%
df
# Out:
#        Unnamed: 0                                          Job Title  \
# index
# 0               0                              Senior Data Scientist
# 1               1                  Data Scientist, Product Analytics
# 2               2                               Data Science Manager
# 3               3                                       Data Analyst
# 4               4                             Director, Data Science
# ...           ...                                                ...
# 4375         3904                                  AWS Data Engineer
# 4376         3905                              Data Analyst â Junior
# 4377         3906                   Security Analytics Data Engineer
# 4378         3907                   Security Analytics Data Engineer
# 4379         3908  Patient Safety Physician or Safety Scientist -...
#
#                     Salary Estimate  \
# index
# 0      $111K-$181K (Glassdoor est.)
# 1      $111K-$181K (Glassdoor est.)
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply'],
#       dtype='object')

# %%
df.drop(columns='Unnamed: 0', inplace=True)

# %%
df.head(3)
# Out:
#                                Job Title               Salary Estimate  \
# index
# 0                  Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1      Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
# 2                   Data Science Manager  $111K-$181K (Glassdoor est.)
#
#                                          Job Description  Rating  \
# index
# 0      ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...     3.5
# 1      At Noom, we use scientifically proven methods ...     4.5
# 2      Decode_M\n\nhttps://www.decode-m.com/\n\nData ...    -1.0
#
#        Company Name      Location      Headquarters                    Size  \
# index
# 0       Hopper\n3.5  New York, NY  Montreal, Canada   501 to 1000 employees
# 1      Noom US\n4.5  New York, NY      New York, NY  1001 to 5000 employees
# 2          Decode_M  New York, NY      New York, NY       1 to 50 employees
#
#        Founded  Type of ownership                   Industry  \
# index
# ...

# %%
df.shape
# Out:
# (3909, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3909 entries, 0 to 4379
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          3909 non-null   object
#  1   Salary Estimate    3909 non-null   object
#  2   Job Description    3909 non-null   object
#  3   Rating             3909 non-null   float64
#  4   Company Name       3909 non-null   object
#  5   Location           3909 non-null   object
#  6   Headquarters       3909 non-null   object
#  7   Size               3909 non-null   object
#  8   Founded            3909 non-null   int64
#  9   Type of ownership  3909 non-null   object
#  10  Industry           3909 non-null   object
#  11  Sector             3909 non-null   object
#  12  Revenue            3909 non-null   object
#  13  Competitors        3909 non-null   object
#  14  Easy Apply         3909 non-null   object
# dtypes: float64(1), int64(1), object(13)
# ...

# %%
df2 = pd.read_csv('dataset/DataAnalyst.csv', encoding="latin")

# %%
df2.head(10)
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
# 5           5                                       Data Analyst
# 6           6                       Business/Data Analyst (FP&A)
# 7           7                               Data Science Analyst
# 8           8                                       Data Analyst
# 9           9                      Data Analyst, Merchant Health
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
# 5  $37K-$66K (Glassdoor est.)
# ...

# %%
df2.shape
# Out:
# (2253, 16)

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply'],
#       dtype='object')

# %%
df2.rename(columns={'Unnamed: 0': 'index'})
# Out:
#       index                                          Job Title  \
# 0         0  Data Analyst, Center on Immigration and Justic...
# 1         1                               Quality Data Analyst
# 2         2  Senior Data Analyst, Insights & Analytics Team...
# 3         3                                       Data Analyst
# 4         4                             Reporting Data Analyst
# ...     ...                                                ...
# 2248   2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249   2249              Senior Data Analyst (Corporate Audit)
# 2250   2250  Technical Business Analyst (SQL, Data analytic...
# 2251   2251                Data Analyst 3, Customer Experience
# 2252   2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# 3      $37K-$66K (Glassdoor est.)
# ...

# %%
df2
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0  Data Analyst, Center on Immigration and Justic...
# 1              1                               Quality Data Analyst
# 2              2  Senior Data Analyst, Insights & Analytics Team...
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250  Technical Business Analyst (SQL, Data analytic...
# 2251        2251                Data Analyst 3, Customer Experience
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# ...

# %%
df2.rename(columns={'Unnamed: 0': 'index'}, inplace=True)

# %%
df2.head(3)
# Out:
#    index                                          Job Title  \
# 0      0  Data Analyst, Center on Immigration and Justic...
# 1      1                               Quality Data Analyst
# 2      2  Senior Data Analyst, Insights & Analytics Team...
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  Weâre looking for a Senior Data Analyst who ...     3.4
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
# 2                         Squarespace\n3.4  New York, NY  New York, NY
#
# ...

# %%
df2.set_index('index', inplace=True)

# %%
df2.shape
# Out:
# (2253, 15)

# %% [markdown]
# ## Dataset
# Having loaded both dataset (DataAnalyst and DataScientist) into DataFrame, only DataScientist dataset will be use for this project as it has more data.

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# __The columns will be prepared in the foolowing order__
# * Company Name: stripping the rating values
# * Location: parsing state code
# * HQ: check if job is in same location or in HQ
# * Size: Parsing (Min, Max, Na) strip -1 with 0
# * Founded: age of company strip -1 with 0
# * Type of ownership: categorize
# * Industry
# * Sector
# * Revenue
# * Competitors

# %%
# Configure the display settings
pd.set_option('display.max_rows', None)

# %%
df.head(20)
# Out:
#                                Job Title               Salary Estimate  \
# index
# 0                  Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1      Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
# 2                   Data Science Manager  $111K-$181K (Glassdoor est.)
# 3                           Data Analyst  $111K-$181K (Glassdoor est.)
# 4                 Director, Data Science  $111K-$181K (Glassdoor est.)
# 5                         Data Scientist  $111K-$181K (Glassdoor est.)
# 6                Quantitative Researcher  $111K-$181K (Glassdoor est.)
# 7        Quantitative Research Associate  $111K-$181K (Glassdoor est.)
# 8                           AI Scientist  $111K-$181K (Glassdoor est.)
# 9                Quantitative Researcher  $111K-$181K (Glassdoor est.)
# 10                        Data Scientist  $111K-$181K (Glassdoor est.)
# 11       Data Scientist/Machine Learning  $111K-$181K (Glassdoor est.)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3909 entries, 0 to 4379
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          3909 non-null   object
#  1   Salary Estimate    3909 non-null   object
#  2   Job Description    3909 non-null   object
#  3   Rating             3909 non-null   float64
#  4   Company Name       3909 non-null   object
#  5   Location           3909 non-null   object
#  6   Headquarters       3909 non-null   object
#  7   Size               3909 non-null   object
#  8   Founded            3909 non-null   int64
#  9   Type of ownership  3909 non-null   object
#  10  Industry           3909 non-null   object
#  11  Sector             3909 non-null   object
#  12  Revenue            3909 non-null   object
#  13  Competitors        3909 non-null   object
#  14  Easy Apply         3909 non-null   object
# dtypes: float64(1), int64(1), object(13)
# ...

# %% [markdown]
# ### Job Title: Categorizing  job title into different field of career

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply'],
#       dtype='object')

# %%
# Created a function to iterate through the Series for data scientist  job listing title

def job_cat(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'Data Engineer'
    elif 'data analyst' in title.lower():
        return 'data analyst'
    elif 'machine learning' in title.lower():
        return 'machine learning'
    elif 'business' in title.lower():
        return 'business i/da'
    else:
        return 'na'

# %%
# Created a function to iterate through the Series for level of job listing title

def seniority(level):
    if 'senior' in level.lower() or 'sr' in level.lower() or 'lead' in level.lower() or 'principal' in level.lower() or 'manager' in level.lower():
        return 'senior'
    elif 'junior' in level.lower():
        return 'junior'
    else:
        return 'na'

# %%
df['job_cat'] = df['Job Title'].apply(job_cat)

# %%
df['job_cat'].value_counts()
# Out:
# na                  1201
# data scientist       984
# data analyst         747
# Data Engineer        742
# machine learning     140
# business i/da         95
# Name: job_cat, dtype: int64

# %%
df['entry_level'] = df['Job Title'].apply(seniority)

# %%
df['entry_level'].value_counts()
# Out:
# na        2881
# senior     993
# junior      35
# Name: entry_level, dtype: int64

# %% [markdown]
# ### Salary Estimate: parsing (Min, Max, Hourly)

# %%
df['Salary Estimate'].head(5)
# Out:
# index
# 0    $111K-$181K (Glassdoor est.)
# 1    $111K-$181K (Glassdoor est.)
# 2    $111K-$181K (Glassdoor est.)
# 3    $111K-$181K (Glassdoor est.)
# 4    $111K-$181K (Glassdoor est.)
# Name: Salary Estimate, dtype: object

# %%
#Hourly Salary 

df['hourly'] = df['Salary Estimate'].apply(lambda x: 1 if 'per hour' in x.lower() else 0)

# %%
df['hourly'].value_counts()
# Out:
# 0    3888
# 1      21
# Name: hourly, dtype: int64

# %%
# removing (Glassdoor est.), $ and K 

salary_est = df['Salary Estimate'].apply(lambda x: x.split('(')[0].replace('$', '').replace('K', ''))

# %%
salary_est = salary_est.apply(lambda x: x.lower().replace('per hour', '').strip())

# %%
salary_est.head()
# Out:
# index
# 0    111-181
# 1    111-181
# 2    111-181
# 3    111-181
# 4    111-181
# Name: Salary Estimate, dtype: object

# %%
# Minimum Salary

df['min_salary'] = salary_est.apply(lambda x: x.split('-')[0])

# %%
#Conver the Series to integer

df['min_salary'] = df['min_salary'].astype('int')
df['min_salary'].head(3)
# Out:
# index
# 0    111
# 1    111
# 2    111
# Name: min_salary, dtype: int32

# %%
# Maximum Salary

df['max_salary'] = salary_est.apply(lambda x: x.split('-')[1])

# %%
# Conver the Series to integer

df['max_salary'] = df['max_salary'].astype('int')
df['max_salary'].head(3)
# Out:
# index
# 0    181
# 1    181
# 2    181
# Name: max_salary, dtype: int32

# %%
# Average Salary

df['Avg_salary'] = (df['min_salary'] + df['max_salary']) / 2

# %%
df['Avg_salary'].head()
# Out:
# index
# 0    146.0
# 1    146.0
# 2    146.0
# 3    146.0
# 4    146.0
# Name: Avg_salary, dtype: float64

# %% [markdown]
# ### Job Desc.: parsing (python, R, Spark, Aws, Excel, Sql, etc..)

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'job_cat', 'entry_level', 'hourly', 'min_salary',
#        'max_salary', 'Avg_salary'],
#       dtype='object')

# %% [markdown]
#     Skill/Tools required that is found in the job listing

# %%
# Python
df['Python_req'] = df['Job Description'].apply(lambda x: 1 if 'python' in x.lower() else 0)

# %%
df['Python_req'].value_counts()
# Out:
# 1    2057
# 0    1852
# Name: Python_req, dtype: int64

# %%
# R Studio
df['RStudio_req'] = df['Job Description'].apply(lambda x: 1 if 'r studio' in x.lower() or 'r-studio' in x.lower() else 0 )

# %%
df['RStudio_req'].value_counts()
# Out:
# 0    3891
# 1      18
# Name: RStudio_req, dtype: int64

# %%
# Saprk
df['Spark_req'] = df['Job Description'].apply(lambda x: 1 if 'spark' in x.lower() or 'apache spark' in x.lower() else 0 )

# %%
df['Spark_req'].value_counts()
# Out:
# 0    3012
# 1     897
# Name: Spark_req, dtype: int64

# %%
# AWS
df['Aws_req'] = df['Job Description'].apply(lambda x: 1 if 'aws' in x.lower() else 0 )

# %%
df['Aws_req'].value_counts()
# Out:
# 0    2960
# 1     949
# Name: Aws_req, dtype: int64

# %%
# Excel
df['Excel_req'] = df['Job Description'].apply(lambda x: 1 if 'excel' in x.lower() else 0 )

# %%
df['Excel_req'].value_counts()
# Out:
# 0    2054
# 1    1855
# Name: Excel_req, dtype: int64

# %% [markdown]
# ### Rating: replace -1 with 0

# %%
df['Rating'].head(10)
# Out:
# index
# 0    3.5
# 1    4.5
# 2   -1.0
# 3    3.4
# 4    3.4
# 5    2.9
# 6    4.4
# 7   -1.0
# 8    5.0
# 9    4.8
# Name: Rating, dtype: float64

# %%
df['Rating'].replace(-1.0, 0.0, inplace=True)

# %%
df['Rating'].head(5)
# Out:
# index
# 0    3.5
# 1    4.5
# 2    0.0
# 3    3.4
# 4    3.4
# Name: Rating, dtype: float64

# %% [markdown]
# ### Company Name: stripping the rating values

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'job_cat', 'entry_level', 'hourly', 'min_salary',
#        'max_salary', 'Avg_salary', 'Python_req', 'RStudio_req', 'Spark_req',
#        'Aws_req', 'Excel_req'],
#       dtype='object')

# %%
df['Company Name'].head(10)
# Out:
# index
# 0                        Hopper\n3.5
# 1                       Noom US\n4.5
# 2                           Decode_M
# 3              Sapphire Digital\n3.4
# 4    United Entertainment Group\n3.4
# 5                 IFG Companies\n2.9
# 6                  PDT Partners\n4.4
# 7             Enlightenment Research
# 8                         Paige\n5.0
# 9                   Jane Street\n4.8
# Name: Company Name, dtype: object

# %%
df['Company_nm'] = df.apply(lambda x: x['Company Name'] if x['Rating'] == 0 else x['Company Name'][:-4], axis=1)

# %%
df['Company_nm'].head(10)
# Out:
# index
# 0                        Hopper
# 1                       Noom US
# 2                      Decode_M
# 3              Sapphire Digital
# 4    United Entertainment Group
# 5                 IFG Companies
# 6                  PDT Partners
# 7        Enlightenment Research
# 8                         Paige
# 9                   Jane Street
# Name: Company_nm, dtype: object

# %% [markdown]
# ### Location: parsing state code

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'job_cat', 'entry_level', 'hourly', 'min_salary',
#        'max_salary', 'Avg_salary', 'Python_req', 'RStudio_req', 'Spark_req',
#        'Aws_req', 'Excel_req', 'Company_nm'],
#       dtype='object')

# %%
df['Location'].head(5)
# Out:
# index
# 0     New York, NY
# 1     New York, NY
# 2     New York, NY
# 3    Lyndhurst, NJ
# 4     New York, NY
# Name: Location, dtype: object

# %%
df['Job_state'] = df['Location'].apply(lambda x: x.split(',')[1])

# %%
df['Job_state'].head(5)
# Out:
# index
# 0     NY
# 1     NY
# 2     NY
# 3     NJ
# 4     NY
# Name: Job_state, dtype: object

# %%
df['Job_state'].value_counts()
# Out:
#  TX                1253
#  CA                1069
#  IL                 363
#  PA                 324
#  NY                 313
#  AZ                 295
#  OH                 177
#  FL                  69
#  NJ                  32
#  DE                  10
#  United Kingdom       4
# Name: Job_state, dtype: int64

# %%
df['Job_state'] = df['Job_state'].apply(lambda x: x.replace('United Kingdom', 'UK'))

# %%
df['Job_state'].value_counts()
# Out:
#  TX    1253
#  CA    1069
#  IL     363
#  PA     324
#  NY     313
#  AZ     295
#  OH     177
#  FL      69
#  NJ      32
#  DE      10
#  UK       4
# Name: Job_state, dtype: int64

# %% [markdown]
# #### Headquarter: check if job is in same location or in HQ

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'job_cat', 'entry_level', 'hourly', 'min_salary',
#        'max_salary', 'Avg_salary', 'Python_req', 'RStudio_req', 'Spark_req',
#        'Aws_req', 'Excel_req', 'Company_nm', 'Job_state'],
#       dtype='object')

# %%
df['Headquarters'].head(20)
# Out:
# index
# 0           Montreal, Canada
# 1               New York, NY
# 2               New York, NY
# 3              Lyndhurst, NJ
# 4               New York, NY
# 5               Hartford, CT
# 6               New York, NY
# 7               New York, NY
# 8               New York, NY
# 9               New York, NY
# 10              New York, NY
# 11              New York, NY
# 12              New York, NY
# 13              Stamford, CT
# 14              New York, NY
# 15              New York, NY
# 16              Brooklyn, NY
# 17    London, United Kingdom
# 18              Brooklyn, NY
# 19              New York, NY
# Name: Headquarters, dtype: object

# %%
df['Same_state'] = df.apply(lambda x: 1 if x['Location'] in x['Headquarters'] else 0, axis=1)

# %%
df['Same_state'].value_counts()
# Out:
# 0    2688
# 1    1221
# Name: Same_state, dtype: int64

# %% [markdown]
# #### Size: Parsing (Min, Max, Na) strip -1 with 0

# %%
df['Size'].value_counts()
# Out:
# 10000+ employees           993
# 51 to 200 employees        563
# 1001 to 5000 employees     553
# 1 to 50 employees          550
# 201 to 500 employees       418
# 501 to 1000 employees      307
# -1                         229
# 5001 to 10000 employees    219
# Unknown                     77
# Name: Size, dtype: int64

# %%
df['Size'].replace({'-1': 'Na', 'Unknown': 'Na' }, inplace=True)

# %%
df['Size'].value_counts()
# Out:
# 10000+ employees           993
# 51 to 200 employees        563
# 1001 to 5000 employees     553
# 1 to 50 employees          550
# 201 to 500 employees       418
# 501 to 1000 employees      307
# Na                         306
# 5001 to 10000 employees    219
# Name: Size, dtype: int64

# %% [markdown]
# #### Founded:
# Get the age of company while stripping -1 with 0.

# %%
df['Founded'].head(10)
# Out:
# index
# 0    2007
# 1    2008
# 2      -1
# 3    2019
# 4    2007
# 5    1985
# 6    1993
# 7      -1
# 8    2018
# 9    2000
# Name: Founded, dtype: int64

# %%
df['Founded'].replace(-1, 0, inplace=True)

# %%
df['Founded'].head(10)
# Out:
# index
# 0    2007
# 1    2008
# 2       0
# 3    2019
# 4    2007
# 5    1985
# 6    1993
# 7       0
# 8    2018
# 9    2000
# Name: Founded, dtype: int64

# %%
df['Age'] = df['Founded'].apply(lambda x: x if x == 0 else 2022 - x)

# %%
df['Age'].head(10)
# Out:
# index
# 0    15
# 1    14
# 2     0
# 3     3
# 4    15
# 5    37
# 6    29
# 7     0
# 8     4
# 9    22
# Name: Age, dtype: int64

# %% [markdown]
# #### Type of ownership: categorize

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'job_cat', 'entry_level', 'hourly', 'min_salary',
#        'max_salary', 'Avg_salary', 'Python_req', 'RStudio_req', 'Spark_req',
#        'Aws_req', 'Excel_req', 'Company_nm', 'Job_state', 'Same_state', 'Age'],
#       dtype='object')

# %%
df['Type of ownership'].value_counts()
# Out:
# Company - Private                 1933
# Company - Public                  1114
# -1                                 229
# Nonprofit Organization             207
# Subsidiary or Business Segment     160
# Government                          91
# College / University                77
# Unknown                             38
# Contract                            17
# Hospital                            16
# Private Practice / Firm             12
# School / School District             5
# Other Organization                   5
# Self-employed                        4
# Franchise                            1
# Name: Type of ownership, dtype: int64

# %%
df['Type of ownership'].replace({'-1': 'Na','Unknown': 'Na'}, inplace=True)

# %%
df['Type of ownership'].value_counts()
# Out:
# Company - Private                 1933
# Company - Public                  1114
# Na                                 267
# Nonprofit Organization             207
# Subsidiary or Business Segment     160
# Government                          91
# College / University                77
# Contract                            17
# Hospital                            16
# Private Practice / Firm             12
# School / School District             5
# Other Organization                   5
# Self-employed                        4
# Franchise                            1
# Name: Type of ownership, dtype: int64

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'job_cat', 'entry_level', 'hourly', 'min_salary',
#        'max_salary', 'Avg_salary', 'Python_req', 'RStudio_req', 'Spark_req',
#        'Aws_req', 'Excel_req', 'Company_nm', 'Job_state', 'Same_state', 'Age'],
#       dtype='object')

# %% [markdown]
# #### Industry: categorize

# %%
df['Industry'].head(20)
# Out:
# index
# 0                             Travel Agencies
# 1                   Health, Beauty, & Fitness
# 2                                          -1
# 3                                    Internet
# 4                     Advertising & Marketing
# 5                          Insurance Carriers
# 6       Investment Banking & Asset Management
# 7                                          -1
# 8     Enterprise Software & Network Solutions
# 9       Investment Banking & Asset Management
# 10    Enterprise Software & Network Solutions
# 11                                   Internet
# 12    Enterprise Software & Network Solutions
# 13      Investment Banking & Asset Management
# 14      Investment Banking & Asset Management
# 15                    Advertising & Marketing
# 16                        Other Retail Stores
# 17                                 Consulting
# 18                        Other Retail Stores
# 19                     Research & Development
# Name: Industry, dtype: object

# %%
df['Industry'].value_counts()
# Out:
# -1                                          546
# IT Services                                 472
# Staffing & Outsourcing                      313
# Biotech & Pharmaceuticals                   293
# Computer Hardware & Software                264
# Internet                                    238
# Health Care Services & Hospitals            197
# Consulting                                  166
# Enterprise Software & Network Solutions     150
# Investment Banking & Asset Management       109
# Advertising & Marketing                      93
# Insurance Carriers                           91
# Colleges & Universities                      84
# Banks & Credit Unions                        64
# Accounting                                   64
# Research & Development                       60
# Federal Agencies                             57
# Lending                                      41
# Aerospace & Defense                          37
# Video Games                                  30
# ...

# %%
df['Industry'].replace('-1', 'Others', inplace=True)

# %%
df['Industry'].head()
# Out:
# index
# 0              Travel Agencies
# 1    Health, Beauty, & Fitness
# 2                       Others
# 3                     Internet
# 4      Advertising & Marketing
# Name: Industry, dtype: object

# %%
df['Sector'].head(10)
# Out:
# index
# 0          Travel & Tourism
# 1         Consumer Services
# 2                        -1
# 3    Information Technology
# 4         Business Services
# 5                 Insurance
# 6                   Finance
# 7                        -1
# 8    Information Technology
# 9                   Finance
# Name: Sector, dtype: object

# %%
df['Sector'].value_counts()
# Out:
# Information Technology                1124
# Business Services                      679
# -1                                     546
# Biotech & Pharmaceuticals              293
# Finance                                270
# Health Care                            197
# Insurance                              109
# Education                              101
# Manufacturing                           87
# Government                              82
# Media                                   75
# Retail                                  72
# Accounting & Legal                      71
# Aerospace & Defense                     37
# Oil, Gas, Energy & Utilities            34
# Telecommunications                      21
# Consumer Services                       20
# Non-Profit                              18
# Construction, Repair & Maintenance      16
# Transportation & Logistics              16
# Real Estate                             12
# Arts, Entertainment & Recreation        10
# ...

# %%
df['Sector'].replace('-1', 'Others', inplace=True)

# %%
df['Sector'].head(10)
# Out:
# index
# 0          Travel & Tourism
# 1         Consumer Services
# 2                    Others
# 3    Information Technology
# 4         Business Services
# 5                 Insurance
# 6                   Finance
# 7                    Others
# 8    Information Technology
# 9                   Finance
# Name: Sector, dtype: object

# %%
df['Revenue'].head(20)
# Out:
# index
# 0             Unknown / Non-Applicable
# 1             Unknown / Non-Applicable
# 2             Unknown / Non-Applicable
# 3             Unknown / Non-Applicable
# 4             Unknown / Non-Applicable
# 5             Unknown / Non-Applicable
# 6             Unknown / Non-Applicable
# 7             Unknown / Non-Applicable
# 8             Unknown / Non-Applicable
# 9             Unknown / Non-Applicable
# 10            Unknown / Non-Applicable
# 11          $100 to $500 million (USD)
# 12    $500 million to $1 billion (USD)
# 13            Unknown / Non-Applicable
# 14            Unknown / Non-Applicable
# 15            Unknown / Non-Applicable
# 16          $100 to $500 million (USD)
# 17          $100 to $500 million (USD)
# 18          $100 to $500 million (USD)
# 19            Unknown / Non-Applicable
# Name: Revenue, dtype: object

# %%
df['Revenue'].value_counts()
# Out:
# Unknown / Non-Applicable            1163
# $10+ billion (USD)                   599
# $100 to $500 million (USD)           338
# -1                                   229
# $50 to $100 million (USD)            214
# $2 to $5 billion (USD)               211
# $10 to $25 million (USD)             191
# $1 to $2 billion (USD)               180
# $1 to $5 million (USD)               170
# $25 to $50 million (USD)             143
# $5 to $10 billion (USD)              133
# Less than $1 million (USD)           124
# $500 million to $1 billion (USD)     114
# $5 to $10 million (USD)              100
# Name: Revenue, dtype: int64

# %%
df['Revenue'].replace({'-1': 'Others', 'Unknown / Non-Applicable': 'Others'}, inplace=True)

# %%
df['Revenue'].value_counts()
# Out:
# Others                              1392
# $10+ billion (USD)                   599
# $100 to $500 million (USD)           338
# $50 to $100 million (USD)            214
# $2 to $5 billion (USD)               211
# $10 to $25 million (USD)             191
# $1 to $2 billion (USD)               180
# $1 to $5 million (USD)               170
# $25 to $50 million (USD)             143
# $5 to $10 billion (USD)              133
# Less than $1 million (USD)           124
# $500 million to $1 billion (USD)     114
# $5 to $10 million (USD)              100
# Name: Revenue, dtype: int64

# %%
df.to_csv('dataset/data_salary_cleaned.csv')
